# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * r.text是json格式的string
# * json.loads()是將json字符串轉換為dict字典類型

# %%
'''
Your Code
'''
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11188978618","type":"PushEvent","actor":{"id":10609578,"login":"Priyankasivakumar","display_login":"Priyankasivakumar","gravatar_id":"","url":"https://api.github.com/users/Priyankasivakumar","avatar_url":"https://avatars.githubusercontent.com/u/10609578?"},"repo":{"id":231036301,"name":"PriyankaParent/Repo1","url":"https://api.github.com/repos/PriyankaParent/Repo1"},"payload":{"push_id":4452923762,"size":1,"distinct_size":1,"ref":"refs/heads/PriyankaBranch2","head":"c6776aa145e79891c3bb38b3a061aae8a6fed7e2","before":"356a8b76e7797fcb81059ad164857520fe126225","commits":[{"sha":"c6776aa145e79891c3bb38b3a061aae8a6fed7e2","author":{"email":"priyavicky1994@gmail.com","name":"Priyankasivakumar"},"message":"Created File\\n\\nCreated a new file in branch 2 after getting push access","distinct":true,"url":"https://api.github.com/repos/PriyankaParent/Repo1/commits/c6776aa145e79891c3bb38b3a061aae8a6fed7e2"}]},"public":true,"created_at":"2020-01-02T07:52:54Z"},{"id":"11188978617","type":"CreateEvent","actor":{"id":59411843,"login":"Debug-2020","display_login":"Debug-2020","gravatar_id":"","url":"https://api.github.com/users/Debug-2020","avatar_url":"https://avatars.githubusercontent.com/u/59411843?"},"repo":{"id":231333726,"name":"Debug-2020/Answers-4118-56483-Sorting","url":"https://api.github.com/repos/Debug-2020/Answers-4118-56483-Sorting"},"payload":{"ref":null,"ref_type":"repository","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2020-01-02T07:52:54Z"},{"id":"11188978613","type":"PullRequestEvent","actor":{"id":35003177,"login":"cracycupcakes","display_login":"cracycupcakes","gravatar_id":"","url":"https://api.github.com/users/cracycupcakes","avatar_url":"https://avatars.githubusercontent.com/u/35003177?"},"repo":{"id":231315554,"name":"cracycupcakes/matrixStats","url":"https://api.github.com/repos/cracycupcakes/matrixStats"},"payload":{"action":"opened","number":1,"pull_request":{"url":"https://api.github.com/repos/cracycupcakes/matrixStats/pulls/1","id":358578371,"node_id":"MDExOlB1bGxSZXF1ZXN0MzU4NTc4Mzcx","html_url":"https://github.com/cracycupcakes/matrixStats/pull/1","diff_url":"https://github.com/cracycupcakes/matrixStats/pull/1.diff","patch_url":"https://github.com/cracycupcakes/matrixStats/pull/1.patch","issue_url":"https://api.github.com/repos/cracycupcakes/matrixStats/issues/1","number":1,"state":"open","locked":false,"title":"a2nlwpweb093","user":{"login":"cracycupcakes","id":35003177,"node_id":"MDQ6VXNlcjM1MDAzMTc3","avatar_url":"https://avatars1.githubusercontent.com/u/35003177?v=4","gravatar_id":"","url":"https://api.github.com/users/cracycupcakes","html_url":"https://github.com/cracycupcakes","followers_url":"https://api.github.com/users/cracycupcakes/followers","following_url":"https://api.github.com/users/cracycupcakes/following{/other_user}","gists_url":"https://api.github.com/users/cracycupcakes/gists{/gist_id}","starred_url":"https://api.github.com/users/cracycupcakes/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/cracycupcakes/subscriptions","organizations_url":"https://api.github.com/users/cracycupcakes/orgs","repos_url":"https://api.github.com/users/cracycupcakes/repos","events_url":"https://api.github.com/users/cracycupcakes/events{/privacy}","received_events_url":"https://api.github.com/users/cracycupcakes/received_events","type":"User","site_admin":false},"body":"","created_at":"2020-01-02T07:52:54Z","updated_at":"2020-01-02T07:52:54Z","closed_at":null,"merged_at":null,"merge_commit_sha":null,"assignee":null,"assignees":[],"requested_reviewers":[],"requested_teams":[],"labels":[],"milestone":null,"commits_url":"https://api.github.com/repos/cracycupcakes/matrixStats/pulls/1/commits","review_comments_url":"https://api.github.com/repos/cracycupcakes/matrixStats/pulls/1/comments","review_comment_url":"https://api.github.com/repos/cracycupcakes/matrixStats/pulls/comments{/number}","comments_url":"https://api.github.com/repos/cracy ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '11188978618',
#   'type': 'PushEvent',
#   'actor': {'id': 10609578,
#    'login': 'Priyankasivakumar',
#    'display_login': 'Priyankasivakumar',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Priyankasivakumar',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10609578?'},
#   'repo': {'id': 231036301,
#    'name': 'PriyankaParent/Repo1',
#    'url': 'https://api.github.com/repos/PriyankaParent/Repo1'},
#   'payload': {'push_id': 4452923762,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/PriyankaBranch2',
#    'head': 'c6776aa145e79891c3bb38b3a061aae8a6fed7e2',
#    'before': '356a8b76e7797fcb81059ad164857520fe126225',
#    'commits': [{'sha': 'c6776aa145e79891c3bb38b3a061aae8a6fed7e2',
#      'author': {'email': 'priyavicky1994@gmail.com',
#       'name': 'Priyankasivakumar'},
#      'message': 'Created File\n\nCreated a new file in branch 2 after getting push access',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PriyankaParent/Repo1/commits/c6776aa145e79891c3bb38b3a061aae8a6fed7e2'}]},
#   'public': True,
#   'created_at': '2020-01-02T07:52:54Z'},
#  {'id': '11188978617',
#   'type': 'CreateEvent',
#   'actor': {'id': 59411843,
#    'login': 'Debug-2020',
#    'display_login': 'Debug-2020',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Debug-2020',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59411843?'},
#   'repo': {'id': 231333726,
#    'name': 'Debug-2020/Answers-4118-56483-Sorting',
#    'url': 'https://api.github.com/repos/Debug-2020/Answers-4118-56483-Sorting'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-01-02T07:52:54Z'},
#  {'id': '11188978613',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 35003177,
#    'login': 'cracycupcakes',
#    'display_login': 'cracycupcakes',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cracycupcakes',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35003177?'},
#   'repo': {'id': 231315554,
#    'name': 'cracycupcakes/matrixStats',
#    'url': 'https://api.github.com/repos/cracycupcakes/matrixStats'},
#   'payload': {'action': 'opened',
#    'number': 1,
#    'pull_request': {'url': 'https://api.github.com/repos/cracycupcakes/matrixStats/pulls/1',
#     'id': 358578371,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzU4NTc4Mzcx',
#     'html_url': 'https://github.com/cracycupcakes/matrixStats/pull/1',
#     'diff_url': 'https://github.com/cracycupcakes/matrixStats/pull/1.diff',
#     'patch_url': 'https://github.com/cracycupcakes/matrixStats/pull/1.patch',
#     'issue_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/issues/1',
#     'number': 1,
#     'state': 'open',
#     'locked': False,
#     'title': 'a2nlwpweb093',
#     'user': {'login': 'cracycupcakes',
#      'id': 35003177,
#      'node_id': 'MDQ6VXNlcjM1MDAzMTc3',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/35003177?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/cracycupcakes',
#      'html_url': 'https://github.com/cracycupcakes',
#      'followers_url': 'https://api.github.com/users/cracycupcakes/followers',
#      'following_url': 'https://api.github.com/users/cracycupcakes/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/cracycupcakes/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/cracycupcakes/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/cracycupcakes/subscriptions',
#      'organizations_url': 'https://api.github.com/users/cracycupcakes/orgs',
#      'repos_url': 'https://api.github.com/users/cracycupcakes/repos',
#      'events_url': 'https://api.github.com/users/cracycupcakes/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/cracycupcakes/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2020-01-02T07:52:54Z',
#     'updated_at': '2020-01-02T07:52:54Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/pulls/1/commits',
#     'review_comments_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/pulls/1/comments',
#     'review_comment_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/issues/1/comments',
#     'statuses_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/statuses/43913f2d93ab0802aacb17c11d2167c15a678457',
#     'head': {'label': 'cracycupcakes:develop',
#      'ref': 'develop',
#      'sha': '43913f2d93ab0802aacb17c11d2167c15a678457',
#      'user': {'login': 'cracycupcakes',
#       'id': 35003177,
#       'node_id': 'MDQ6VXNlcjM1MDAzMTc3',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/35003177?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/cracycupcakes',
#       'html_url': 'https://github.com/cracycupcakes',
#       'followers_url': 'https://api.github.com/users/cracycupcakes/followers',
#       'following_url': 'https://api.github.com/users/cracycupcakes/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/cracycupcakes/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/cracycupcakes/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/cracycupcakes/subscriptions',
#       'organizations_url': 'https://api.github.com/users/cracycupcakes/orgs',
#       'repos_url': 'https://api.github.com/users/cracycupcakes/repos',
#       'events_url': 'https://api.github.com/users/cracycupcakes/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/cracycupcakes/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 231315554,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMzEzMTU1NTQ=',
#       'name': 'matrixStats',
#       'full_name': 'cracycupcakes/matrixStats',
#       'private': False,
#       'owner': {'login': 'cracycupcakes',
#        'id': 35003177,
#        'node_id': 'MDQ6VXNlcjM1MDAzMTc3',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/35003177?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/cracycupcakes',
#        'html_url': 'https://github.com/cracycupcakes',
#        'followers_url': 'https://api.github.com/users/cracycupcakes/followers',
#        'following_url': 'https://api.github.com/users/cracycupcakes/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/cracycupcakes/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/cracycupcakes/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/cracycupcakes/subscriptions',
#        'organizations_url': 'https://api.github.com/users/cracycupcakes/orgs',
#        'repos_url': 'https://api.github.com/users/cracycupcakes/repos',
#        'events_url': 'https://api.github.com/users/cracycupcakes/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/cracycupcakes/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/cracycupcakes/matrixStats',
#       'description': 'R package: Methods that Apply to Rows and Columns of Matrices (and to Vectors) ',
#       'fork': True,
#       'url': 'https://api.github.com/repos/cracycupcakes/matrixStats',
#       'forks_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/forks',
#       'keys_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/teams',
#       'hooks_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/hooks',
#       'issue_events_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/events',
#       'assignees_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/tags',
#       'blobs_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/languages',
#       'stargazers_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/stargazers',
#       'contributors_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/contributors',
#       'subscribers_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/subscribers',
#       'subscription_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/subscription',
#       'commits_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/merges',
#       'archive_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/downloads',
#       'issues_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/deployments',
#       'created_at': '2020-01-02T05:45:48Z',
#       'updated_at': '2020-01-02T06:56:33Z',
#       'pushed_at': '2020-01-02T07:52:04Z',
#       'git_url': 'git://github.com/cracycupcakes/matrixStats.git',
#       'ssh_url': 'git@github.com:cracycupcakes/matrixStats.git',
#       'clone_url': 'https://github.com/cracycupcakes/matrixStats.git',
#       'svn_url': 'https://github.com/cracycupcakes/matrixStats',
#       'homepage': 'https://cran.r-project.org/package=matrixStats',
#       'size': 3290,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'R',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 1,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'develop'}},
#     'base': {'label': 'cracycupcakes:patch-1',
#      'ref': 'patch-1',
#      'sha': '730132c7b86d83e6c63a0235804d839fe6d325d3',
#      'user': {'login': 'cracycupcakes',
#       'id': 35003177,
#       'node_id': 'MDQ6VXNlcjM1MDAzMTc3',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/35003177?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/cracycupcakes',
#       'html_url': 'https://github.com/cracycupcakes',
#       'followers_url': 'https://api.github.com/users/cracycupcakes/followers',
#       'following_url': 'https://api.github.com/users/cracycupcakes/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/cracycupcakes/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/cracycupcakes/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/cracycupcakes/subscriptions',
#       'organizations_url': 'https://api.github.com/users/cracycupcakes/orgs',
#       'repos_url': 'https://api.github.com/users/cracycupcakes/repos',
#       'events_url': 'https://api.github.com/users/cracycupcakes/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/cracycupcakes/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 231315554,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMzEzMTU1NTQ=',
#       'name': 'matrixStats',
#       'full_name': 'cracycupcakes/matrixStats',
#       'private': False,
#       'owner': {'login': 'cracycupcakes',
#        'id': 35003177,
#        'node_id': 'MDQ6VXNlcjM1MDAzMTc3',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/35003177?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/cracycupcakes',
#        'html_url': 'https://github.com/cracycupcakes',
#        'followers_url': 'https://api.github.com/users/cracycupcakes/followers',
#        'following_url': 'https://api.github.com/users/cracycupcakes/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/cracycupcakes/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/cracycupcakes/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/cracycupcakes/subscriptions',
#        'organizations_url': 'https://api.github.com/users/cracycupcakes/orgs',
#        'repos_url': 'https://api.github.com/users/cracycupcakes/repos',
#        'events_url': 'https://api.github.com/users/cracycupcakes/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/cracycupcakes/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/cracycupcakes/matrixStats',
#       'description': 'R package: Methods that Apply to Rows and Columns of Matrices (and to Vectors) ',
#       'fork': True,
#       'url': 'https://api.github.com/repos/cracycupcakes/matrixStats',
#       'forks_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/forks',
#       'keys_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/teams',
#       'hooks_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/hooks',
#       'issue_events_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/events',
#       'assignees_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/tags',
#       'blobs_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/languages',
#       'stargazers_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/stargazers',
#       'contributors_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/contributors',
#       'subscribers_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/subscribers',
#       'subscription_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/subscription',
#       'commits_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/merges',
#       'archive_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/downloads',
#       'issues_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/cracycupcakes/matrixStats/deployments',
#       'created_at': '2020-01-02T05:45:48Z',
#       'updated_at': '2020-01-02T06:56:33Z',
#       'pushed_at': '2020-01-02T07:52:04Z',
#       'git_url': 'git://github.com/cracycupcakes/matrixStats.git',
#       'ssh_url': 'git@github.com:cracycupcakes/matrixStats.git',
#       'clone_url': 'https://github.com/cracycupcakes/matrixStats.git',
#       'svn_url': 'https://github.com/cracycupcakes/matrixStats',
#       'homepage': 'https://cran.r-project.org/package=matrixStats',
#       'size': 3290,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'R',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 1,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'develop'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/cracycupcakes/matrixStats/pulls/1'},
#      'html': {'href': 'https://github.com/cracycupcakes/matrixStats/pull/1'},
#      'issue': {'href': 'https://api.github.com/repos/cracycupcakes/matrixStats/issues/1'},
#      'comments': {'href': 'https://api.github.com/repos/cracycupcakes/matrixStats/issues/1/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/cracycupcakes/matrixStats/pulls/1/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/cracycupcakes/matrixStats/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/cracycupcakes/matrixStats/pulls/1/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/cracycupcakes/matrixStats/statuses/43913f2d93ab0802aacb17c11d2167c15a678457'}},
#     'author_association': 'OWNER',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 17,
#     'deletions': 0,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-01-02T07:52:54Z'},
#  {'id': '11188978609',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 4297676,
#    'login': 'cfillion',
#    'display_login': 'cfillion',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cfillion',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4297676?'},
#   'repo': {'id': 21614326,
#    'name': 'reaper-oss/sws',
#    'url': 'https://api.github.com/repos/reaper-oss/sws'},
#   'payload': {'action': 'opened',
#    'number': 1273,
#    'pull_request': {'url': 'https://api.github.com/repos/reaper-oss/sws/pulls/1273',
#     'id': 358578369,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzU4NTc4MzY5',
#     'html_url': 'https://github.com/reaper-oss/sws/pull/1273',
#     'diff_url': 'https://github.com/reaper-oss/sws/pull/1273.diff',
#     'patch_url': 'https://github.com/reaper-oss/sws/pull/1273.patch',
#     'issue_url': 'https://api.github.com/repos/reaper-oss/sws/issues/1273',
#     'number': 1273,
#     'state': 'open',
#     'locked': False,
#     'title': 'allow using scripts with a toggle state in cycle action conditions',
#     'user': {'login': 'cfillion',
#      'id': 4297676,
#      'node_id': 'MDQ6VXNlcjQyOTc2NzY=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/4297676?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/cfillion',
#      'html_url': 'https://github.com/cfillion',
#      'followers_url': 'https://api.github.com/users/cfillion/followers',
#      'following_url': 'https://api.github.com/users/cfillion/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/cfillion/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/cfillion/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/cfillion/subscriptions',
#      'organizations_url': 'https://api.github.com/users/cfillion/orgs',
#      'repos_url': 'https://api.github.com/users/cfillion/repos',
#      'events_url': 'https://api.github.com/users/cfillion/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/cfillion/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'This also disables checking whether Main Section scripts have a toggle state set. This is because scripts cannot have a toggle state until they are run. Leaving the check enabled would prevent these cycle actions from being registered when starting up REAPER.',
#     'created_at': '2020-01-02T07:52:53Z',
#     'updated_at': '2020-01-02T07:52:53Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/reaper-oss/sws/pulls/1273/commits',
#     'review_comments_url': 'https://api.github.com/repos/reaper-oss/sws/pulls/1273/comments',
#     'review_comment_url': 'https://api.github.com/repos/reaper-oss/sws/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/reaper-oss/sws/issues/1273/comments',
#     'statuses_url': 'https://api.github.com/repos/reaper-oss/sws/statuses/1096268d71a9a9292348abdf1b87363a74ee69d8',
#     'head': {'label': 'cfillion:cyclaction-script-conditions',
#      'ref': 'cyclaction-script-conditions',
#      'sha': '1096268d71a9a9292348abdf1b87363a74ee69d8',
#      'user': {'login': 'cfillion',
#       'id': 4297676,
#       'node_id': 'MDQ6VXNlcjQyOTc2NzY=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/4297676?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/cfillion',
#       'html_url': 'https://github.com/cfillion',
#       'followers_url': 'https://api.github.com/users/cfillion/followers',
#       'following_url': 'https://api.github.com/users/cfillion/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/cfillion/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/cfillion/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/cfillion/subscriptions',
#       'organizations_url': 'https://api.github.com/users/cfillion/orgs',
#       'repos_url': 'https://api.github.com/users/cfillion/repos',
#       'events_url': 'https://api.github.com/users/cfillion/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/cfillion/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 84708250,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk4NDcwODI1MA==',
#       'name': 'sws',
#       'full_name': 'cfillion/sws',
#       'private': False,
#       'owner': {'login': 'cfillion',
#        'id': 4297676,
#        'node_id': 'MDQ6VXNlcjQyOTc2NzY=',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/4297676?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/cfillion',
#        'html_url': 'https://github.com/cfillion',
#        'followers_url': 'https://api.github.com/users/cfillion/followers',
#        'following_url': 'https://api.github.com/users/cfillion/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/cfillion/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/cfillion/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/cfillion/subscriptions',
#        'organizations_url': 'https://api.github.com/users/cfillion/orgs',
#        'repos_url': 'https://api.github.com/users/cfillion/repos',
#        'events_url': 'https://api.github.com/users/cfillion/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/cfillion/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/cfillion/sws',
#       'description': 'The SWS extension is a collection of features that seamlessly integrate into REAPER, the Digital Audio Workstation (DAW) software by Cockos, Inc',
#       'fork': True,
#       'url': 'https://api.github.com/repos/cfillion/sws',
#       'forks_url': 'https://api.github.com/repos/cfillion/sws/forks',
#       'keys_url': 'https://api.github.com/repos/cfillion/sws/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/cfillion/sws/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/cfillion/sws/teams',
#       'hooks_url': 'https://api.github.com/repos/cfillion/sws/hooks',
#       'issue_events_url': 'https://api.github.com/repos/cfillion/sws/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/cfillion/sws/events',
#       'assignees_url': 'https://api.github.com/repos/cfillion/sws/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/cfillion/sws/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/cfillion/sws/tags',
#       'blobs_url': 'https://api.github.com/repos/cfillion/sws/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/cfillion/sws/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/cfillion/sws/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/cfillion/sws/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/cfillion/sws/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/cfillion/sws/languages',
#       'stargazers_url': 'https://api.github.com/repos/cfillion/sws/stargazers',
#       'contributors_url': 'https://api.github.com/repos/cfillion/sws/contributors',
#       'subscribers_url': 'https://api.github.com/repos/cfillion/sws/subscribers',
#       'subscription_url': 'https://api.github.com/repos/cfillion/sws/subscription',
#       'commits_url': 'https://api.github.com/repos/cfillion/sws/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/cfillion/sws/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/cfillion/sws/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/cfillion/sws/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/cfillion/sws/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/cfillion/sws/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/cfillion/sws/merges',
#       'archive_url': 'https://api.github.com/repos/cfillion/sws/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/cfillion/sws/downloads',
#       'issues_url': 'https://api.github.com/repos/cfillion/sws/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/cfillion/sws/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/cfillion/sws/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/cfillion/sws/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/cfillion/sws/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/cfillion/sws/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/cfillion/sws/deployments',
#       'created_at': '2017-03-12T07:31:55Z',
#       'updated_at': '2019-12-05T19:10:30Z',
#       'pushed_at': '2020-01-02T07:52:00Z',
#       'git_url': 'git://github.com/cfillion/sws.git',
#       'ssh_url': 'git@github.com:cfillion/sws.git',
#       'clone_url': 'https://github.com/cfillion/sws.git',
#       'svn_url': 'https://github.com/cfillion/sws',
#       'homepage': None,
#       'size': 20448,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'C++',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'reaper-oss:master',
#      'ref': 'master',
#      'sha': '08d3c6fce05191347092a55df6dd5d4764f1de9c',
#      'user': {'login': 'reaper-oss',
#       'id': 20407984,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjIwNDA3OTg0',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/20407984?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/reaper-oss',
#       'html_url': 'https://github.com/reaper-oss',
#       'followers_url': 'https://api.github.com/users/reaper-oss/followers',
#       'following_url': 'https://api.github.com/users/reaper-oss/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/reaper-oss/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/reaper-oss/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/reaper-oss/subscriptions',
#       'organizations_url': 'https://api.github.com/users/reaper-oss/orgs',
#       'repos_url': 'https://api.github.com/users/reaper-oss/repos',
#       'events_url': 'https://api.github.com/users/reaper-oss/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/reaper-oss/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 21614326,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMTYxNDMyNg==',
#       'name': 'sws',
#       'full_name': 'reaper-oss/sws',
#       'private': False,
#       'owner': {'login': 'reaper-oss',
#        'id': 20407984,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjIwNDA3OTg0',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/20407984?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/reaper-oss',
#        'html_url': 'https://github.com/reaper-oss',
#        'followers_url': 'https://api.github.com/users/reaper-oss/followers',
#        'following_url': 'https://api.github.com/users/reaper-oss/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/reaper-oss/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/reaper-oss/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/reaper-oss/subscriptions',
#        'organizations_url': 'https://api.github.com/users/reaper-oss/orgs',
#        'repos_url': 'https://api.github.com/users/reaper-oss/repos',
#        'events_url': 'https://api.github.com/users/reaper-oss/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/reaper-oss/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/reaper-oss/sws',
#       'description': 'The SWS extension is a collection of features that seamlessly integrate into REAPER, the Digital Audio Workstation (DAW) software by Cockos, Inc',
#       'fork': False,
#       'url': 'https://api.github.com/repos/reaper-oss/sws',
#       'forks_url': 'https://api.github.com/repos/reaper-oss/sws/forks',
#       'keys_url': 'https://api.github.com/repos/reaper-oss/sws/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/reaper-oss/sws/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/reaper-oss/sws/teams',
#       'hooks_url': 'https://api.github.com/repos/reaper-oss/sws/hooks',
#       'issue_events_url': 'https://api.github.com/repos/reaper-oss/sws/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/reaper-oss/sws/events',
#       'assignees_url': 'https://api.github.com/repos/reaper-oss/sws/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/reaper-oss/sws/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/reaper-oss/sws/tags',
#       'blobs_url': 'https://api.github.com/repos/reaper-oss/sws/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/reaper-oss/sws/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/reaper-oss/sws/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/reaper-oss/sws/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/reaper-oss/sws/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/reaper-oss/sws/languages',
#       'stargazers_url': 'https://api.github.com/repos/reaper-oss/sws/stargazers',
#       'contributors_url': 'https://api.github.com/repos/reaper-oss/sws/contributors',
#       'subscribers_url': 'https://api.github.com/repos/reaper-oss/sws/subscribers',
#       'subscription_url': 'https://api.github.com/repos/reaper-oss/sws/subscription',
#       'commits_url': 'https://api.github.com/repos/reaper-oss/sws/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/reaper-oss/sws/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/reaper-oss/sws/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/reaper-oss/sws/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/reaper-oss/sws/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/reaper-oss/sws/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/reaper-oss/sws/merges',
#       'archive_url': 'https://api.github.com/repos/reaper-oss/sws/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/reaper-oss/sws/downloads',
#       'issues_url': 'https://api.github.com/repos/reaper-oss/sws/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/reaper-oss/sws/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/reaper-oss/sws/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/reaper-oss/sws/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/reaper-oss/sws/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/reaper-oss/sws/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/reaper-oss/sws/deployments',
#       'created_at': '2014-07-08T13:48:01Z',
#       'updated_at': '2019-12-30T19:12:34Z',
#       'pushed_at': '2020-01-02T05:24:29Z',
#       'git_url': 'git://github.com/reaper-oss/sws.git',
#       'ssh_url': 'git@github.com:reaper-oss/sws.git',
#       'clone_url': 'https://github.com/reaper-oss/sws.git',
#       'svn_url': 'https://github.com/reaper-oss/sws',
#       'homepage': None,
#       'size': 20139,
#       'stargazers_count': 198,
#       'watchers_count': 198,
#       'language': 'C++',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 49,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 362,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 49,
#       'open_issues': 362,
#       'watchers': 198,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/reaper-oss/sws/pulls/1273'},
#      'html': {'href': 'https://github.com/reaper-oss/sws/pull/1273'},
#      'issue': {'href': 'https://api.github.com/repos/reaper-oss/sws/issues/1273'},
#      'comments': {'href': 'https://api.github.com/repos/reaper-oss/sws/issues/1273/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/reaper-oss/sws/pulls/1273/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/reaper-oss/sws/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/reaper-oss/sws/pulls/1273/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/reaper-oss/sws/statuses/1096268d71a9a9292348abdf1b87363a74ee69d8'}},
#     'author_association': 'COLLABORATOR',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 27,
#     'deletions': 11,
#     'changed_files': 4}},
#   'public': True,
#   'created_at': '2020-01-02T07:52:54Z',
#   'org': {'id': 20407984,
#    'login': 'reaper-oss',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/reaper-oss',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20407984?'}},
#  {'id': '11188978606',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 46596279,
#    'name': 'Lombiq/Orchard-Confirm-Leave',
#    'url': 'https://api.github.com/repos/Lombiq/Orchard-Confirm-Leave'},
#   'payload': {'push_id': 4452923756,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/orchard-upgrade-1.10',
#    'head': 'a16600a00165a8b2deee296a8fedd7316202152d',
#    'before': 'a16600a00165a8b2deee296a8fedd7316202152d',
#    'commits': []},
#   'public': True,
#   'created_at': '2020-01-02T07:52:54Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '11188978598',
#   'type': 'PushEvent',
#   'actor': {'id': 39792018,
#    'login': 'AigarsPeda',
#    'display_login': 'AigarsPeda',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AigarsPeda',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39792018?'},
#   'repo': {'id': 230880927,
#    'name': 'AigarsPeda/todo-react-typescript',
#    'url': 'https://api.github.com/repos/AigarsPeda/todo-react-typescript'},
#   'payload': {'push_id': 4452923745,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '04551a9510d3a415aab82793565c5cf2594685fb',
#    'before': 'd4e0cfc8841772f26fd5b4cb7e0914d8ac272fe8',
#    'commits': [{'sha': '04551a9510d3a415aab82793565c5cf2594685fb',
#      'author': {'email': 'aigarspeda@gmail.com', 'name': 'Aigars Peda'},
#      'message': 'Added screenshot',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AigarsPeda/todo-react-typescript/commits/04551a9510d3a415aab82793565c5cf2594685fb'}]},
#   'public': True,
#   'created_at': '2020-01-02T07:52:54Z'},
#  {'id': '11188978605',
#   'type': 'CreateEvent',
#   'actor': {'id': 18676440,
#    'login': 'remeber951',
#    'display_login': 'remeber951',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/remeber951',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18676440?'},
#   'repo': {'id': 230884772,
#    'name': 'remeber951/191230_ReactAdmin',
#    'url': 'https://api.github.com/repos/remeber951/191230_ReactAdmin'},
#   'payload': {'ref': 'dev',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'React的后台管理应用',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-01-02T07:52:54Z'},
#  {'id': '11188978589',
#   'type': 'PushEvent',
#   'actor': {'id': 29973148,
#    'login': 'toyangdon',
#    'display_login': 'toyangdon',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/toyangdon',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29973148?'},
#   'repo': {'id': 231333595,
#    'name': 'toyangdon/node-problem-detector-arm64',
#    'url': 'https://api.github.com/repos/toyangdon/node-problem-detector-arm64'},
#   'payload': {'push_id': 4452923744,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '585334a48067eae9f99941723158c2a3907aa4f8',
#    'before': '86abcb7c5791d23db457978305d37d41544cc8c7',
#    'commits': [{'sha': '585334a48067eae9f99941723158c2a3907aa4f8',
#      'author': {'email': 'toyangdon@163.com', 'name': 'toyangdon'},
#      'message': 'Update Dockerfile',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/toyangdon/node-problem-detector-arm64/commits/585334a48067eae9f99941723158c2a3907aa4f8'}]},
#   'public': True,
#   'created_at': '2020-01-02T07:52:54Z'},
#  {'id': '11188978593',
#   'type': 'CreateEvent',
#   'actor': {'id': 3897569,
#    'login': 'avinashsahu2013',
#    'display_login': 'avinashsahu2013',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/avinashsahu2013',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3897569?'},
#   'repo': {'id': 231333718,
#    'name': 'avinashsahu2013/IMF',
#    'url': 'https://api.github.com/repos/avinashsahu2013/IMF'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-01-02T07:52:54Z'},
#  {'id': '11188978586',
#   'type': 'PushEvent',
#   'actor': {'id': 34417022,
#    'login': 'ellementul',
#    'display_login': 'ellementul',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ellementul',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34417022?'},
#   'repo': {'id': 117242819,
#    'name': 'ellementul/typesjs',
#    'url': 'https://api.github.com/repos/ellementul/typesjs'},
#   'payload': {'push_id': 4452923748,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '645d8c063ab5e510fc932863655a0ba142bf686e',
#    'before': '0e1a41f5988b3ca6f82066735fb1f7d422a5a491',
#    'commits': [{'sha': '645d8c063ab5e510fc932863655a0ba142bf686e',
#      'author': {'email': 'ananev.ivan.ur@ya.ru', 'name': 'ellementul'},
#      'message': 'Fixed answer valid in module "Switch"',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ellementul/typesjs/commits/645d8c063ab5e510fc932863655a0ba142bf686e'}]},
#   'public': True,
#   'created_at': '2020-01-02T07:52:54Z'},
#  {'id': '11188978590',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 9116238,
#    'login': 'krzysztofzuraw',
#    'display_login': 'krzysztofzuraw',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/krzysztofzuraw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9116238?'},
#   'repo': {'id': 207623230,
#    'name': 'krzysztofzuraw/generator-typescript-react-parcel',
#    'url': 'https://api.github.com/repos/krzysztofzuraw/generator-typescript-react-parcel'},
#   'payload': {'action': 'closed',
#    'number': 24,
#    'pull_request': {'url': 'https://api.github.com/repos/krzysztofzuraw/generator-typescript-react-parcel/pulls/24',
#     'id': 358451243,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzU4NDUxMjQz',
#     'html_url': 'https://github.com/krzysztofzuraw/generator-typescript-react-parcel/pull/24',
#     'diff_url': 'https://github.com/krzysztofzuraw/generator-typescript-react-parcel/pull/24.diff',
#     'patch_url': 'https://github.com/krzysztofzuraw/generator-typescript-react-parcel/pull/24.patch',
#     'issue_url': 'https://api.github.com/repos/krzysztofzuraw/generator-typescript-react-parcel/issues/24',
#     'number': 24,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Bump eslint-plugin-prettier from 3.1.1 to 3.1.2',
#     'user': {'login': 'dependabot-preview[bot]',
#      'id': 27856297,
#      'node_id': 'MDM6Qm90Mjc4NTYyOTc=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/2141?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot-preview',
#      'followers_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
# ...
#     'labels_url': 'https://api.github.com/repos/bayesmans/mao-seminar/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/bayesmans/mao-seminar/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/bayesmans/mao-seminar/deployments',
#     'created_at': '2020-01-02T07:52:53Z',
#     'updated_at': '2019-12-30T12:54:29Z',
#     'pushed_at': '2019-12-04T07:24:54Z',
#     'git_url': 'git://github.com/bayesmans/mao-seminar.git',
#     'ssh_url': 'git@github.com:bayesmans/mao-seminar.git',
#     'clone_url': 'https://github.com/bayesmans/mao-seminar.git',
#     'svn_url': 'https://github.com/bayesmans/mao-seminar',
#     'homepage': 'https://www.amazon.co.jp/dp/4863542178/',
#     'size': 8937,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2020-01-02T07:52:53Z'},
#  {'id': '11188978553',
#   'type': 'CreateEvent',
#   'actor': {'id': 2670228,
#    'login': 'wmtorode',
#    'display_login': 'wmtorode',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wmtorode',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2670228?'},
#   'repo': {'id': 208236269,
#    'name': 'BattletechModders/BiggerDrops',
#    'url': 'https://api.github.com/repos/BattletechModders/BiggerDrops'},
#   'payload': {'ref': '0.0.4',
#    'ref_type': 'tag',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-01-02T07:52:53Z',
#   'org': {'id': 45464973,
#    'login': 'BattletechModders',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/BattletechModders',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45464973?'}},
#  {'id': '11188978549',
#   'type': 'PushEvent',
#   'actor': {'id': 57213420,
#    'login': 'He-XiaoLong',
#    'display_login': 'He-XiaoLong',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/He-XiaoLong',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57213420?'},
#   'repo': {'id': 230376547,
#    'name': 'He-XiaoLong/final-assignment-open-source',
#    'url': 'https://api.github.com/repos/He-XiaoLong/final-assignment-open-source'},
#   'payload': {'push_id': 4452923728,
#    'size': 3,
#    'distinct_size': 3,
#    'ref': 'refs/heads/master',
#    'head': 'a5a1f04d0c57d5fc14651482a118cf0510f83b26',
#    'before': 'f3cf73018700d1aa694f617e5411f9c00151f063',
#    'commits': [{'sha': 'f2c3dcde8037db49396460493d6098dbcacdb493',
#      'author': {'email': '55396722+cb1473258684@users.noreply.github.com',
#       'name': 'cb1473258684'},
#      'message': '51195100002提交作业',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/He-XiaoLong/final-assignment-open-source/commits/f2c3dcde8037db49396460493d6098dbcacdb493'},
#     {'sha': '2f5be6a1c4201c7b8059d7ece1ad6190bfe1ac6a',
#      'author': {'email': '55396722+cb1473258684@users.noreply.github.com',
#       'name': 'cb1473258684'},
#      'message': '删除无关文件',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/He-XiaoLong/final-assignment-open-source/commits/2f5be6a1c4201c7b8059d7ece1ad6190bfe1ac6a'},
#     {'sha': 'a5a1f04d0c57d5fc14651482a118cf0510f83b26',
#      'author': {'email': '57213420+He-XiaoLong@users.noreply.github.com',
#       'name': 'He-XiaoLong'},
#      'message': 'Merge pull request #88 from cb1473258684/51195100002\n\n51195100002陈贝',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/He-XiaoLong/final-assignment-open-source/commits/a5a1f04d0c57d5fc14651482a118cf0510f83b26'}]},
#   'public': True,
#   'created_at': '2020-01-02T07:52:53Z'},
#  {'id': '11188978550',
#   'type': 'CreateEvent',
#   'actor': {'id': 15265829,
#    'login': 'dreamcontinue',
#    'display_login': 'dreamcontinue',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dreamcontinue',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15265829?'},
#   'repo': {'id': 231333212,
#    'name': 'dreamcontinue/StressConeHeatDetection',
#    'url': 'https://api.github.com/repos/dreamcontinue/StressConeHeatDetection'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-01-02T07:52:53Z'},
#  {'id': '11188978539',
#   'type': 'PushEvent',
#   'actor': {'id': 46258495,
#    'login': 'lonefintech',
#    'display_login': 'lonefintech',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lonefintech',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46258495?'},
#   'repo': {'id': 163577891,
#    'name': 'lonefintech/hugo-contrarian',
#    'url': 'https://api.github.com/repos/lonefintech/hugo-contrarian'},
#   'payload': {'push_id': 4452923713,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '236116631b308f92dc2675eac216251f52382670',
#    'before': '0bd25eebf101a5c8518a15f8d4b3ec793d50d98a',
#    'commits': [{'sha': '236116631b308f92dc2675eac216251f52382670',
#      'author': {'email': '46258495+lonefintech@users.noreply.github.com',
#       'name': 'lonefintech'},
#      'message': 'python update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/lonefintech/hugo-contrarian/commits/236116631b308f92dc2675eac216251f52382670'}]},
#   'public': True,
#   'created_at': '2020-01-02T07:52:53Z'},
#  {'id': '11188978547',
#   'type': 'CreateEvent',
#   'actor': {'id': 53108186,
#    'login': 'codestar-github-bot-1',
#    'display_login': 'codestar-github-bot-1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/codestar-github-bot-1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53108186?'},
#   'repo': {'id': 231333723,
#    'name': 'devhub-blue-sea/org-public-empty-repo-ap-northeast-1',
#    'url': 'https://api.github.com/repos/devhub-blue-sea/org-public-empty-repo-ap-northeast-1'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'Empty Repository created by CFN',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-01-02T07:52:53Z',
#   'org': {'id': 53108288,
#    'login': 'devhub-blue-sea',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/devhub-blue-sea',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53108288?'}},
#  {'id': '11188978540',
#   'type': 'ReleaseEvent',
#   'actor': {'id': 2670228,
#    'login': 'wmtorode',
#    'display_login': 'wmtorode',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wmtorode',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2670228?'},
#   'repo': {'id': 208236269,
#    'name': 'BattletechModders/BiggerDrops',
#    'url': 'https://api.github.com/repos/BattletechModders/BiggerDrops'},
#   'payload': {'action': 'published',
#    'release': {'url': 'https://api.github.com/repos/BattletechModders/BiggerDrops/releases/22547517',
#     'assets_url': 'https://api.github.com/repos/BattletechModders/BiggerDrops/releases/22547517/assets',
#     'upload_url': 'https://uploads.github.com/repos/BattletechModders/BiggerDrops/releases/22547517/assets{?name,label}',
#     'html_url': 'https://github.com/BattletechModders/BiggerDrops/releases/tag/0.0.4',
#     'id': 22547517,
#     'node_id': 'MDc6UmVsZWFzZTIyNTQ3NTE3',
#     'tag_name': '0.0.4',
#     'target_commitish': 'master',
#     'name': '0.0.4',
#     'draft': False,
#     'author': {'login': 'wmtorode',
#      'id': 2670228,
#      'node_id': 'MDQ6VXNlcjI2NzAyMjg=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/2670228?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/wmtorode',
#      'html_url': 'https://github.com/wmtorode',
#      'followers_url': 'https://api.github.com/users/wmtorode/followers',
#      'following_url': 'https://api.github.com/users/wmtorode/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/wmtorode/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/wmtorode/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/wmtorode/subscriptions',
#      'organizations_url': 'https://api.github.com/users/wmtorode/orgs',
#      'repos_url': 'https://api.github.com/users/wmtorode/repos',
#      'events_url': 'https://api.github.com/users/wmtorode/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/wmtorode/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'prerelease': False,
#     'created_at': '2020-01-01T22:22:38Z',
#     'published_at': '2020-01-02T07:52:53Z',
#     'assets': [{'url': 'https://api.github.com/repos/BattletechModders/BiggerDrops/releases/assets/17098060',
#       'id': 17098060,
#       'node_id': 'MDEyOlJlbGVhc2VBc3NldDE3MDk4MDYw',
#       'name': 'BiggerDrops.zip',
#       'label': None,
#       'uploader': {'login': 'wmtorode',
#        'id': 2670228,
#        'node_id': 'MDQ6VXNlcjI2NzAyMjg=',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/2670228?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/wmtorode',
#        'html_url': 'https://github.com/wmtorode',
#        'followers_url': 'https://api.github.com/users/wmtorode/followers',
#        'following_url': 'https://api.github.com/users/wmtorode/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/wmtorode/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/wmtorode/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/wmtorode/subscriptions',
#        'organizations_url': 'https://api.github.com/users/wmtorode/orgs',
#        'repos_url': 'https://api.github.com/users/wmtorode/repos',
#        'events_url': 'https://api.github.com/users/wmtorode/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/wmtorode/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'content_type': 'application/x-zip-compressed',
#       'state': 'uploaded',
#       'size': 36582,
#       'download_count': 0,
#       'created_at': '2020-01-02T07:52:47Z',
#       'updated_at': '2020-01-02T07:52:48Z',
#       'browser_download_url': 'https://github.com/BattletechModders/BiggerDrops/releases/download/0.0.4/BiggerDrops.zip'}],
#     'tarball_url': 'https://api.github.com/repos/BattletechModders/BiggerDrops/tarball/0.0.4',
#     'zipball_url': 'https://api.github.com/repos/BattletechModders/BiggerDrops/zipball/0.0.4',
#     'body': 'Update for 1.8\r\n\r\n- fixes bug with argo upgrades\r\n- fixes an issue with MC Solo and Duo duel contracts'}},
#   'public': True,
#   'created_at': '2020-01-02T07:52:53Z',
#   'org': {'id': 45464973,
#    'login': 'BattletechModders',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/BattletechModders',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45464973?'}},
#  {'id': '11188978536',
#   'type': 'DeleteEvent',
#   'actor': {'id': 6735650,
#    'login': 'gsantner',
#    'display_login': 'gsantner',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gsantner',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6735650?'},
#   'repo': {'id': 53066732,
#    'name': 'gsantner/dandelion',
#    'url': 'https://api.github.com/repos/gsantner/dandelion'},
#   'payload': {'ref': 'dependabot/gradle/junit-junit-4.13',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-01-02T07:52:53Z'},
#  {'id': '11188978534',
#   'type': 'PushEvent',
#   'actor': {'id': 13673199,
#    'login': 'jinchihe',
#    'display_login': 'jinchihe',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jinchihe',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13673199?'},
#   'repo': {'id': 174089158,
#    'name': 'jinchihe/tf-operator',
#    'url': 'https://api.github.com/repos/jinchihe/tf-operator'},
#   'payload': {'push_id': 4452923709,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/add_watch_api',
#    'head': 'f0a7ca9b0a1ee291a628b9de5cec40119754156d',
#    'before': 'a473190742864034d62f3a9abb362829401b3ab2',
#    'commits': [{'sha': 'f0a7ca9b0a1ee291a628b9de5cec40119754156d',
#      'author': {'email': 'hejinchi@cn.ibm.com', 'name': 'Jin Chi He'},
#      'message': 'Add watch function for TFJob python Client API',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jinchihe/tf-operator/commits/f0a7ca9b0a1ee291a628b9de5cec40119754156d'}]},
#   'public': True,
#   'created_at': '2020-01-02T07:52:53Z'},
#  {'id': '11188978528',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 46596221,
#    'name': 'Lombiq/Combinator-TypeScript-Preprocessor',
#    'url': 'https://api.github.com/repos/Lombiq/Combinator-TypeScript-Preprocessor'},
#   'payload': {'push_id': 4452923706,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/dev',
#    'head': '18d66fe7407e3b972dc667e0358f48e41443b2ab',
#    'before': '18d66fe7407e3b972dc667e0358f48e41443b2ab',
#    'commits': []},
#   'public': True,
#   'created_at': '2020-01-02T07:52:53Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '11188978529',
#   'type': 'WatchEvent',
#   'actor': {'id': 59430355,
#    'login': 'Junayet237',
#    'display_login': 'Junayet237',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Junayet237',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59430355?'},
#   'repo': {'id': 123150622,
#    'name': 'AdminPanteam/pt.BTC',
#    'url': 'https://api.github.com/repos/AdminPanteam/pt.BTC'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-01-02T07:52:53Z'},
#  {'id': '11188978526',
#   'type': 'WatchEvent',
#   'actor': {'id': 663786,
#    'login': 'smarteng',
#    'display_login': 'smarteng',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/smarteng',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/663786?'},
#   'repo': {'id': 40648138,
#    'name': 'SegmentFault/HyperDown',
#    'url': 'https://api.github.com/repos/SegmentFault/HyperDown'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-01-02T07:52:53Z',
#   'org': {'id': 6038130,
#    'login': 'SegmentFault',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/SegmentFault',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6038130?'}},
#  {'id': '11188978516',
#   'type': 'PushEvent',
#   'actor': {'id': 59293082,
#    'login': 'lihkg-boy',
#    'display_login': 'lihkg-boy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lihkg-boy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59293082?'},
#   'repo': {'id': 230501783,
#    'name': 'lihkg-backup/thread',
#    'url': 'https://api.github.com/repos/lihkg-backup/thread'},
#   'payload': {'push_id': 4452923697,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8cf93964424aa978ef2bb1fa8f64805be49b431a',
#    'before': '45edeca4fdfa651d4033bb896bb22083a7ea417c',
#    'commits': [{'sha': '8cf93964424aa978ef2bb1fa8f64805be49b431a',
#      'author': {'email': 'lihkg@github.com', 'name': 'lihkg'},
#      'message': 'update 1807539.json 2020-01-02T07:52:50.452Z',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/lihkg-backup/thread/commits/8cf93964424aa978ef2bb1fa8f64805be49b431a'}]},
#   'public': True,
#   'created_at': '2020-01-02T07:52:53Z',
#   'org': {'id': 58919150,
#    'login': 'lihkg-backup',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/lihkg-backup',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58919150?'}}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
'''
Your Code
'''

r=requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel')
response=json.loads(r.text)
print(response)
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel', '@odata.count': 100, 'value': [{'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '2200H029', 'WaterLevel': 145.15}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1730H070', 'WaterLevel': 226.25}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1580H021', 'WaterLevel': 1.28}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1580H017', 'WaterLevel': 25.73}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '2560H019', 'WaterLevel': 4.48}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1580H001', 'WaterLevel': 224.21}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1730H075', 'WaterLevel': 92.83}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '2420H036', 'WaterLevel': 164.37}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '2500H003', 'WaterLevel': 32.2}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1730H066', 'WaterLevel': 138.73}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1730H077', 'WaterLevel': 740.49}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1550H014', 'WaterLevel': 26.75}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1670H004', 'WaterLevel': 2.98}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '2420H019', 'WaterLevel': 109.97}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1650H012', 'WaterLevel': 0.7}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1730H061', 'WaterLevel': 266.23}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1730H072', 'WaterLevel': 248.86}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1540H039', 'WaterLevel': 38.99}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1660H012', 'WaterLevel': 0.14}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '2370H025', 'WaterLevel': 261.61}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1650H009', 'WaterLevel': 0.1}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1730H057', 'WaterLevel': 43.48}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1730H068', 'WaterLevel': 10.14}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1540H037', 'WaterLevel': 32.01}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1650H015', 'WaterLevel': 0.05}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '2370H018', 'WaterLevel': 124.1}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1630H036', 'WaterLevel': 65.83}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1660H009', 'WaterLevel': 4.85}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1730H043', 'WaterLevel': 23.04}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '2420H043', 'WaterLevel': 79.32}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1540H033', 'WaterLevel': 23.4}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1650H010', 'WaterLevel': 0.19}, {'RecordTime': 'Dec 11, 2019 2:20:00 PM', 'StationIdentifier': '1630H030', 'WaterLevel': 1.57}, {'RecordTime': 'Dec 11, 2019 2:20:00 PM', 'StationIdentifier': '1630H032', 'WaterLevel': 0.13}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1650H013', 'WaterLevel': 5.62}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1680H005', 'WaterLevel': 0.11}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '2200H026', 'WaterLevel': 106.73}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1350H031', 'WaterLevel': -0.15}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1630H040', 'WaterLevel': 1.76}, {'RecordTime': 'Dec 11, 2019 2:50:00 PM', 'StationIdentifier': '1630H018', 'WaterLevel': 10.01}, {'RecordTime': 'De ...
